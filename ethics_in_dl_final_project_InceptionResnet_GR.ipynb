# %% [markdown]
# #**Deep Learning Final Project - **
#
# ###CNN Models: Ethical implications in gender classification, CNN Models - InceptionResnetV2
#
# ###**Author: Gomathi Ramesh (gr52@rice.edu)**
#
#    - COMP 647 (DL)
#    - Rice University
#    - Professor:Dr. Arko Barman (DL and NLP courses)(arko.barman@rice.edu)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import json
from collections import Counter

# %%
DATA_DIR = '/content/fairface'
# !unzip /content/drive/MyDrive/FinalProject_DL/fairface-img-margin025-trainval.zip -d /content/drive/MyDrive/FinalProject_DL/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5370.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5596.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5875.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5878.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5879.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5883.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6126.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6132.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6144.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6150.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6340.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7190.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7734.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7747.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7872.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7940.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8065.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8069.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8125.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8202.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8204.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8205.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8268.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8270.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8281.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8291.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8501.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8502.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8505.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8508.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8514.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8517.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8905.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8954.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9832.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10149.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10159.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10224.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10229.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10232.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10234.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10238.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10242.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10624.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10625.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10629.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/107.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/139.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/280.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/466.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/897.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/921.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1388.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1730.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1743.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1811.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1853.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1863.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1869.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2561.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2571.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2574.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2785.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2795.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2796.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2805.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3553.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3556.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3558.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3559.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3568.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3607.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3608.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3610.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3612.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3721.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3722.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3725.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4505.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4519.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4524.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4640.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4647.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4659.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4663.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4668.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5072.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5084.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5102.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5236.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5512.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6641.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6651.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6838.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6845.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6860.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6979.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6981.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6984.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6994.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7153.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7227.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7303.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7312.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7324.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7326.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7393.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7429.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7471.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7509.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7541.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7599.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7630.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7636.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7654.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7988.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7989.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8006.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8011.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8017.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8019.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8841.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8963.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9072.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9074.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9085.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9138.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9144.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9153.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9188.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9213.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9373.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9380.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9386.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9419.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10693.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10886.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/451.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/719.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/765.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/915.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1052.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1385.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1387.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1392.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1395.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1795.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1804.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1810.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1812.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1867.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2559.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2567.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2580.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2581.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2788.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2789.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2797.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2798.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3564.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3567.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3575.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3578.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3611.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3614.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3636.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3723.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4517.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4522.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5082.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5092.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5094.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5235.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5251.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5510.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5515.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6656.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6842.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6843.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6850.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6857.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6977.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7041.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7450.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7647.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7653.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7702.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7732.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8013.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8018.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8772.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8780.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8782.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8821.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8836.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8845.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8846.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8961.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8969.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8970.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8975.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9060.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9068.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9143.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9150.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9205.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9254.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9261.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9266.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9268.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9359.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9363.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9371.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9372.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9421.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10522.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10532.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10691.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10694.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10699.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10874.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10879.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/14.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/92.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/175.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/362.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/363.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/452.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/508.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/510.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/552.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/730.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/732.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/763.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/801.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/877.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/884.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/907.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/937.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1376.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1378.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1386.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1741.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1744.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1745.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1747.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1752.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1799.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1801.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1871.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1874.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1876.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2577.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2579.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2585.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2808.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3557.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3577.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3633.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3720.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3724.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3727.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3728.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3738.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4506.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4508.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4518.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4526.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4641.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4646.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4654.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4662.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5078.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5101.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5249.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5253.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5508.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6840.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6971.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6975.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6976.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7016.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7272.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7307.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7310.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7313.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7403.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7626.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7635.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7643.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7645.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7648.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7993.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8009.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8775.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8825.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8834.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8840.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8842.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9073.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9076.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9087.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9129.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9132.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9133.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9141.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9197.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9210.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9255.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9259.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9365.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9376.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9377.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9423.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10703.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10707.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/140.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/186.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/357.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/551.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/553.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/699.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/740.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/764.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/919.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1377.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1383.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1792.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1798.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1807.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1854.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1856.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1862.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2575.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2786.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2804.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3551.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3554.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3555.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3613.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3623.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3719.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4511.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4512.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4531.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4652.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5090.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5234.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5250.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5520.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5525.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5529.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5534.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5535.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6652.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6654.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6834.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6836.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6841.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6858.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6972.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6988.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6995.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7325.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7409.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7649.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7650.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7651.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7681.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7996.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8773.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8784.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8788.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8790.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8792.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8824.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8826.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8849.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8962.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8964.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9189.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9193.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9198.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9206.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9211.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9217.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9263.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9364.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9366.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10528.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10876.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/138.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/173.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/185.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/279.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/372.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/525.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/664.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/685.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/799.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/800.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/879.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/942.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1380.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1401.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1733.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1738.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1739.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1740.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1748.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1751.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1758.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1800.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1803.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1852.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1855.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1868.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2560.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2565.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2570.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2572.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2576.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2784.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3573.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3621.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3635.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3729.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3730.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3733.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4521.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4530.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4653.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4657.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4661.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5081.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5086.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5093.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5099.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5231.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5247.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5252.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5254.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5509.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5517.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5519.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6646.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6855.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6856.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6859.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6863.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6973.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6974.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6985.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6990.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6993.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7092.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7302.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7304.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7305.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7309.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7311.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7316.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7317.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7319.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7369.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7395.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7396.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7397.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7407.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7631.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7639.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7644.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8003.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8007.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8008.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8770.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8779.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8791.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8822.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8968.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8977.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9066.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9067.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9069.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9071.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9082.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9088.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9091.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9134.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9136.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9139.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9140.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9190.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9192.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9204.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9209.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9216.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9245.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9258.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9264.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9360.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9370.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9422.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10526.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10529.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10538.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10696.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10698.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10706.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10881.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10883.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/187.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/373.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/878.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/882.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/898.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/926.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1389.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1390.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1399.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1731.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1757.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1813.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1864.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1865.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1866.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2569.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2583.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2790.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2803.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2806.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3565.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3574.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3615.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3619.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3625.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3626.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3628.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3732.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3742.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4523.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4527.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4532.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4644.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4645.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4655.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4660.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5076.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5077.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5097.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5239.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5240.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5246.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5514.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5523.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5528.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5533.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6648.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6853.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6992.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7301.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7306.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7394.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7490.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7634.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7640.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7750.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7994.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8778.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8781.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8785.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8789.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8823.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8830.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8833.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8848.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8966.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8972.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9077.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9145.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9201.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9212.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9242.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9249.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9251.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9262.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9265.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9383.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9385.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10513.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10519.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10520.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10527.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10533.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10700.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10880.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10885.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10888.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/18.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/28.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/51.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/74.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/181.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/741.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/909.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/936.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1070.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1402.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1403.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1749.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1793.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1794.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1796.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1806.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1815.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1857.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1870.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2563.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2568.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2573.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2787.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3569.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3576.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3609.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3620.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3629.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3630.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3631.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3634.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3717.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3718.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3734.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3737.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4503.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4504.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4509.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4510.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4513.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4514.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4516.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4642.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4650.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4651.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4664.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4666.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5098.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5100.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5233.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5237.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5238.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5245.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5524.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5530.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5537.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6642.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6650.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6653.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6844.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6991.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7064.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7124.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7249.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7308.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7314.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7322.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7401.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7406.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7408.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7632.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8010.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8012.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8777.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8783.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8787.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8832.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8844.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8979.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9080.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9086.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9131.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9135.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9137.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9149.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9191.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9196.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9203.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9208.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9246.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9250.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9252.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9257.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9267.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9362.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10514.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10524.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10531.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10535.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10689.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10709.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10878.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10887.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10890.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/180.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/257.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/356.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/896.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/920.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1088.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1384.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1394.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1396.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1400.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1734.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1750.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1755.jpg
# ...
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6826.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6832.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6922.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7185.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7215.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7223.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7346.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7356.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7362.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7364.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7417.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7418.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7420.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7421.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7425.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7497.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7502.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7888.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7948.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7957.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7960.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8078.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8089.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8146.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8148.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8152.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8155.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8224.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8437.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8495.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8497.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8526.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8530.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8533.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8535.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8538.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8541.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8627.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8763.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8765.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8928.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9808.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9841.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9849.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9937.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9941.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10205.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10469.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10645.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10859.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10861.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10864.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10867.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10872.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10892.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10898.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10907.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/387.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/429.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/470.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/503.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/504.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/629.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/679.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/721.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/742.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1065.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1223.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1225.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1237.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1642.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1647.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1651.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1690.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1692.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1694.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1697.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1994.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3068.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3417.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3426.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4257.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4258.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4284.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4290.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4293.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4298.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4639.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4689.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4691.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5826.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5830.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6276.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6278.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6280.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6289.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6664.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6666.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6823.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6830.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6920.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6934.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6938.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7174.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7183.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7222.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7349.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7353.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7357.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7366.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7426.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7492.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7768.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7877.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7882.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7884.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8073.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8140.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8143.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8159.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8225.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8489.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8527.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8532.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8542.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8629.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8929.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8936.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9800.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9813.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9816.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9819.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9854.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10020.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10034.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10163.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10174.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10204.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10471.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10866.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/47.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/200.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/750.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/796.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/850.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/864.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/893.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1221.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1224.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1231.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1234.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1645.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1997.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/1998.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/2006.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3055.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3058.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3061.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3067.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3422.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3423.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3424.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3425.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3862.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3866.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/3867.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4245.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4248.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4281.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4282.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4285.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4288.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4297.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4690.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4692.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/4700.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5028.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5033.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5329.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5331.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5341.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/5344.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6275.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6285.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6507.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6517.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6518.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6782.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6813.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6818.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6820.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6822.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6919.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6924.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6933.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/6936.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7176.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7180.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7209.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7350.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7358.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7363.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7411.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7507.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7753.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7754.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/7764.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8074.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8081.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8085.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8157.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8213.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8488.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8491.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8635.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8752.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/8931.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9801.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9807.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9812.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9818.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9821.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9848.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/9857.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10018.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10024.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10025.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10166.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10167.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10171.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10172.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10179.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10200.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10481.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10647.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10648.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10857.jpg
#   inflating: /content/drive/MyDrive/FinalProject_DL/val/10897.jpg

# %%
# !ls /content/drive/MyDrive/FinalProject_DL
# Out:
# fairface-img-margin025-trainval.zip  fairface_label_val.csv  train
# fairface_label_train.csv	     processed_data	     val

# %%
# Set up

class Config:
    """Configuration for FairFace preprocessing"""
    #DATA_DIR = '/kaggle/input/fairface/fairface'
    DATA_DIR = "/content/drive/MyDrive/FinalProject_DL"
    TRAIN_IMG_DIR = os.path.join(DATA_DIR, 'train')
    VAL_IMG_DIR = os.path.join(DATA_DIR, 'val')
    TRAIN_LABELS_CSV = os.path.join(DATA_DIR, 'fairface_label_train.csv')
    VAL_LABELS_CSV = os.path.join(DATA_DIR, 'fairface_label_val.csv')

    #OUTPUT_DIR = '/kaggle/working/processed_data'
    OUTPUT_DIR = "/content/drive/MyDrive/FinalProject_DL/processed_data"

    # Split ratios (combining train/val for new split)
    TRAIN_RATIO = 0.7
    VAL_RATIO = 0.15
    TEST_RATIO = 0.15

    # Image preprocessing
    IMG_SIZE = 224
    NORMALIZE_MEAN = [0.485, 0.456, 0.406]
    NORMALIZE_STD = [0.229, 0.224, 0.225]

    # Random seed for reproducibility
    RANDOM_SEED = 42

    # Batch size for DataLoader
    BATCH_SIZE = 32
    NUM_WORKERS = 2

# Create output directory
os.makedirs(Config.OUTPUT_DIR, exist_ok=True)

# %%
# load data then parse and encode labels

def load_and_parse_labels():
    """
    Load and parse FairFace labels from CSV files using Config paths.

    Returns:
        pd.DataFrame: Combined dataframe with columns:
            - file: image filename
            - age: age group (kept for integrity)
            - gender: target variable (Male/Female)
            - race: protected attribute (7 classes)
            - split_source: original split (train/val)
    """
    print("Loading label files...")
    print(f"Train CSV: {Config.TRAIN_LABELS_CSV}")
    print(f"Val CSV: {Config.VAL_LABELS_CSV}")

    # Load CSVs directly from Config
    train_df = pd.read_csv(Config.TRAIN_LABELS_CSV)
    val_df = pd.read_csv(Config.VAL_LABELS_CSV)

    # Add source split identifier
    train_df['split_source'] = 'train'
    val_df['split_source'] = 'val'

    # Combine datasets
    df = pd.concat([train_df, val_df], ignore_index=True)

    print(f"Total images loaded: {len(df)}")
    print(f"\nDataset columns: {df.columns.tolist()}")

    # Display dataset stats
    print("\n" + "="*60)
    print("DATASET STATISTICS")
    print("="*60)

    print(f"\nGender distribution:")
    print(df['gender'].value_counts())

    print(f"\nRace distribution:")
    print(df['race'].value_counts())

    print(f"\nAge distribution:")
    print(df['age'].value_counts())

    return df

def encode_labels(df):
    """
    Encode categorical labels to numerical values.

    Returns:
        df: DataFrame with added encoded columns
        label_encodings: Dict with encoding mappings
    """
    print("\nEncoding labels...")

    # Gender encoding (binary classification)
    gender_map = {'Male': 0, 'Female': 1}
    df['gender_encoded'] = df['gender'].map(gender_map)

    # Race encoding (protected attribute)
    race_categories = df['race'].unique()
    race_map = {race: idx for idx, race in enumerate(sorted(race_categories))}
    df['race_encoded'] = df['race'].map(race_map)

    label_encodings = {
        'gender': gender_map,
        'race': race_map
    }

    print(f"Gender encoding: {gender_map}")
    print(f"Race encoding: {race_map}")

    # Save encodings
    with open(os.path.join(Config.OUTPUT_DIR, 'label_encodings.json'), 'w') as f:
        json.dump(label_encodings, f, indent=2)

    return df, label_encodings

# %%
# splits

def create_stratified_splits(df):
    """
    Create stratified train/val/test splits maintaining race and gender distribution.

    Returns:
        train_df, val_df, test_df: Split dataframes
    """
    print("\n" + "="*60)
    print("CREATING STRATIFIED SPLITS")
    print("="*60)

    # Create stratification col combining gender and race
    df['stratify_col'] = df['gender'].astype(str) + '_' + df['race'].astype(str)

    # First split: separate test set
    train_val_df, test_df = train_test_split(
        df,
        test_size=Config.TEST_RATIO,
        stratify=df['stratify_col'],
        random_state=Config.RANDOM_SEED
    )

    # Second split: separate train and val
    relative_val_size = Config.VAL_RATIO / (Config.TRAIN_RATIO + Config.VAL_RATIO)
    train_df, val_df = train_test_split(
        train_val_df,
        test_size=relative_val_size,
        stratify=train_val_df['stratify_col'],
        random_state=Config.RANDOM_SEED
    )

    print(f"\nSplit sizes:")
    print(f"  Train: {len(train_df)} ({len(train_df)/len(df)*100:.1f}%)")
    print(f"  Val:   {len(val_df)} ({len(val_df)/len(df)*100:.1f}%)")
    print(f"  Test:  {len(test_df)} ({len(test_df)/len(df)*100:.1f}%)")

    # Verify
    for split_name, split_df in [('Train', train_df), ('Val', val_df), ('Test', test_df)]:
        print(f"\n{split_name} set distribution:")
        print(f"  Gender: {dict(split_df['gender'].value_counts())}")
        print(f"  Race counts: {len(split_df['race'].value_counts())} categories")

    # Save split indices
    split_info = {
        'train_indices': train_df.index.tolist(),
        'val_indices': val_df.index.tolist(),
        'test_indices': test_df.index.tolist(),
        'random_seed': Config.RANDOM_SEED
    }

    with open(os.path.join(Config.OUTPUT_DIR, 'split_indices.json'), 'w') as f:
        json.dump(split_info, f)

    print(f"\nSplit indices saved to: {Config.OUTPUT_DIR}/split_indices.json")

    return train_df, val_df, test_df

# %%
# resizing, cropping, adjust color/brightness/contrast/normalizing/etc
# and creating data loaders

class FairFaceDataset(Dataset):
    """
    PyTorch Dataset for FairFace images with gender classification and race attributes.
    """
    def __init__(self, dataframe, img_dirs, transform=None):
        """
        Args:
            dataframe: DataFrame with image paths and labels
            img_dirs: Dict mapping split_source to image directories
            transform: torchvision transforms to apply
        """
        self.df = dataframe.reset_index(drop=True)
        self.img_dirs = img_dirs
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        # Construct image path
        # The 'file' column contains paths like 'train/12345.jpg' or 'val/67890.jpg'
        # need to extract just the filename and use split_source to get the right directory
        filename = os.path.basename(row['file'])  # Extract just the filename (like '12345.jpg')
        split_source = row['split_source']
        img_path = os.path.join(self.img_dirs[split_source], filename)

        # Load image
        try:
            image = Image.open(img_path).convert('RGB')
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Return a blank image as fallback
            image = Image.new('RGB', (Config.IMG_SIZE, Config.IMG_SIZE))

        # Apply transforms
        if self.transform:
            image = self.transform(image)

        # Prepare labels
        gender_label = row['gender_encoded']
        race_label = row['race_encoded']

        return {
            'image': image,
            'gender': torch.tensor(gender_label, dtype=torch.long),
            'race': torch.tensor(race_label, dtype=torch.long),
            'filename': row['file']
        }

def get_transforms(split='train'):
    """
    Get appropriate transforms for train/val/test splits.

    Args:
        split: 'train', 'val', or 'test'

    Returns:
        torchvision.transforms.Compose
    """
    if split == 'train':
        return transforms.Compose([
            transforms.Resize((Config.IMG_SIZE + 32, Config.IMG_SIZE + 32)),
            transforms.RandomCrop(Config.IMG_SIZE),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
            transforms.ToTensor(),
            transforms.Normalize(mean=Config.NORMALIZE_MEAN, std=Config.NORMALIZE_STD)
        ])
    else:  # val or test
        return transforms.Compose([
            transforms.Resize((Config.IMG_SIZE, Config.IMG_SIZE)),
            transforms.CenterCrop(Config.IMG_SIZE),
            transforms.ToTensor(),
            transforms.Normalize(mean=Config.NORMALIZE_MEAN, std=Config.NORMALIZE_STD)
        ])

def create_dataloaders(train_df, val_df, test_df):
    """
    Create PyTorch DataLoaders for all splits.

    Returns:
        train_loader, val_loader, test_loader
    """
    print("\n" + "="*60)
    print("CREATING DATALOADERS")
    print("="*60)

    # Image directory mapping
    img_dirs = {
        'train': Config.TRAIN_IMG_DIR,
        'val': Config.VAL_IMG_DIR
    }

    # Create datasets
    train_dataset = FairFaceDataset(
        train_df,
        img_dirs,
        transform=get_transforms('train')
    )

    val_dataset = FairFaceDataset(
        val_df,
        img_dirs,
        transform=get_transforms('val')
    )

    test_dataset = FairFaceDataset(
        test_df,
        img_dirs,
        transform=get_transforms('test')
    )

    # Create dataloaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=Config.BATCH_SIZE,
        shuffle=True,
        num_workers=Config.NUM_WORKERS,
        pin_memory=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=Config.BATCH_SIZE,
        shuffle=False,
        num_workers=Config.NUM_WORKERS,
        pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=Config.BATCH_SIZE,
        shuffle=False,
        num_workers=Config.NUM_WORKERS,
        pin_memory=True
    )

    print(f"\nDataLoader created:")
    print(f"  Train batches: {len(train_loader)}")
    print(f"  Val batches:   {len(val_loader)}")
    print(f"  Test batches:  {len(test_loader)}")

    return train_loader, val_loader, test_loader

# %%
# test and baseline fairness stats

def verify_dataloaders(train_loader, val_loader, test_loader):
    """
    Verify dataloaders work correctly and check for data leakage.
    """
    print("\n" + "="*60)
    print("VERIFYING DATALOADERS")
    print("="*60)

    # Test loading a batch
    print("\nTesting batch loading...")
    batch = next(iter(train_loader))

    print(f"Batch keys: {batch.keys()}")
    print(f"Image batch shape: {batch['image'].shape}")
    print(f"Gender labels shape: {batch['gender'].shape}")
    print(f"Race labels shape: {batch['race'].shape}")
    print(f"Gender labels (first 10): {batch['gender'][:10].tolist()}")
    print(f"Race labels (first 10): {batch['race'][:10].tolist()}")

    # Check image value range
    img_min = batch['image'].min().item()
    img_max = batch['image'].max().item()
    print(f"\nImage value range: [{img_min:.3f}, {img_max:.3f}]")

    print("\n DataLoaders verified successfully!")

def compute_fairness_metrics_baseline(train_df, val_df, test_df):
    """
    Compute baseline fairness statistics before model training.
    """
    print("\n" + "="*60)
    print("BASELINE FAIRNESS STATISTICS")
    print("="*60)

    for split_name, split_df in [('Train', train_df), ('Val', val_df), ('Test', test_df)]:
        print(f"\n{split_name} Set:")

        # Gender distribution by race
        print("\nGender distribution by race:")
        crosstab = pd.crosstab(split_df['race'], split_df['gender'], normalize='index') * 100
        print(crosstab.round(2))

        # Check for imbalances
        for race in split_df['race'].unique():
            race_subset = split_df[split_df['race'] == race]
            gender_dist = race_subset['gender'].value_counts(normalize=True)
            imbalance_ratio = gender_dist.max() / gender_dist.min()
            print(f"  {race}: imbalance ratio = {imbalance_ratio:.2f}")

# %%
# main

def main():
    """
    Main execution pipeline for FairFace data preprocessing.
    """
    print("="*60)
    print("FAIRFACE DATA PREPROCESSING PIPELINE")
    print("="*60)

    # Set random seeds for reproducibility
    np.random.seed(Config.RANDOM_SEED)
    torch.manual_seed(Config.RANDOM_SEED)

    # Step 1: Load and parse labels
    df = load_and_parse_labels()

    # Step 2: Encode labels
    df, label_encodings = encode_labels(df)

    # Step 3: Create stratified splits
    train_df, val_df, test_df = create_stratified_splits(df)

    # Step 4: Save split DataFrames
    train_df.to_csv(os.path.join(Config.OUTPUT_DIR, 'train_split.csv'), index=False)
    val_df.to_csv(os.path.join(Config.OUTPUT_DIR, 'val_split.csv'), index=False)
    test_df.to_csv(os.path.join(Config.OUTPUT_DIR, 'test_split.csv'), index=False)
    print(f"\nSplit CSV files saved to: {Config.OUTPUT_DIR}")

    # Step 5: Create DataLoaders
    train_loader, val_loader, test_loader = create_dataloaders(train_df, val_df, test_df)

    # Step 6: Verify DataLoaders
    verify_dataloaders(train_loader, val_loader, test_loader)

    # Step 7: Compute baseline fairness metrics
    compute_fairness_metrics_baseline(train_df, val_df, test_df)

    print("\n" + "="*60)
    print("PREPROCESSING COMPLETE!")
    print("="*60)
    print(f"\nOutputs saved to: {Config.OUTPUT_DIR}")
    print("Files created:")
    print("  - label_encodings.json")
    print("  - split_indices.json")
    print("  - train_split.csv")
    print("  - val_split.csv")
    print("  - test_split.csv")

    return train_loader, val_loader, test_loader, label_encodings

# %%
if __name__ == "__main__":
    train_loader, val_loader, test_loader, label_encodings = main()
# Out:
# ============================================================
# FAIRFACE DATA PREPROCESSING PIPELINE
# ============================================================
# Loading label files...
# Train CSV: /content/drive/MyDrive/FinalProject_DL/fairface_label_train.csv
# Val CSV: /content/drive/MyDrive/FinalProject_DL/fairface_label_val.csv
# Total images loaded: 97698
#
# Dataset columns: ['file', 'age', 'gender', 'race', 'service_test', 'split_source']
#
# ============================================================
# DATASET STATISTICS
# ============================================================
#
# Gender distribution:
# gender
# Male      51778
# Female    45920
# Name: count, dtype: int64
#
# Race distribution:
# race
# White              18612
# Latino_Hispanic    14990
# East Asian         13837
# Indian             13835
# Black              13789
# Southeast Asian    12210
# Middle Eastern     10425
# Name: count, dtype: int64
#
# Age distribution:
# age
# 20-29           28898
# 30-39           21580
# 40-49           12097
# 3-9             11764
# 10-19           10284
# 50-59            7024
# 60-69            3100
# 0-2              1991
# more than 70      960
# Name: count, dtype: int64
#
# Encoding labels...
# Gender encoding: {'Male': 0, 'Female': 1}
# Race encoding: {'Black': 0, 'East Asian': 1, 'Indian': 2, 'Latino_Hispanic': 3, 'Middle Eastern': 4, 'Southeast Asian': 5, 'White': 6}
#
# ============================================================
# CREATING STRATIFIED SPLITS
# ============================================================
#
# Split sizes:
#   Train: 68388 (70.0%)
#   Val:   14655 (15.0%)
#   Test:  14655 (15.0%)
#
# Train set distribution:
#   Gender: {'Male': np.int64(36245), 'Female': np.int64(32143)}
#   Race counts: 7 categories
#
# Val set distribution:
#   Gender: {'Male': np.int64(7765), 'Female': np.int64(6890)}
#   Race counts: 7 categories
#
# Test set distribution:
#   Gender: {'Male': np.int64(7768), 'Female': np.int64(6887)}
#   Race counts: 7 categories
#
# Split indices saved to: /content/drive/MyDrive/FinalProject_DL/processed_data/split_indices.json
#
# Split CSV files saved to: /content/drive/MyDrive/FinalProject_DL/processed_data
#
# ============================================================
# CREATING DATALOADERS
# ============================================================
#
# DataLoader created:
#   Train batches: 2138
#   Val batches:   458
#   Test batches:  458
#
# ============================================================
# VERIFYING DATALOADERS
# ============================================================
#
# Testing batch loading...
# Error loading image /content/drive/MyDrive/FinalProject_DL/train/58479.jpg: [Errno 5] Input/output error: '/content/drive/MyDrive/FinalProject_DL/train/58479.jpg'Error loading image /content/drive/MyDrive/FinalProject_DL/train/23577.jpg: [Errno 5] Input/output error: '/content/drive/MyDrive/FinalProject_DL/train/23577.jpg'
#
# Batch keys: dict_keys(['image', 'gender', 'race', 'filename'])
# Image batch shape: torch.Size([32, 3, 224, 224])
# Gender labels shape: torch.Size([32])
# Race labels shape: torch.Size([32])
# Gender labels (first 10): [0, 0, 1, 1, 1, 1, 1, 1, 0, 1]
# Race labels (first 10): [1, 1, 6, 6, 6, 2, 6, 2, 6, 3]
#
# Image value range: [-2.118, 2.640]
#
#  DataLoaders verified successfully!
#
# ============================================================
# BASELINE FAIRNESS STATISTICS
# ============================================================
#
# Train Set:
#
# Gender distribution by race:
# gender           Female   Male
# race
# Black             49.99  50.01
# East Asian        49.97  50.03
# Indian            48.22  51.78
# Latino_Hispanic   50.33  49.67
# Middle Eastern    31.10  68.90
# Southeast Asian   48.02  51.98
# White             47.22  52.78
#   Southeast Asian: imbalance ratio = 1.08
#   Black: imbalance ratio = 1.00
#   Latino_Hispanic: imbalance ratio = 1.01
#   East Asian: imbalance ratio = 1.00
#   Middle Eastern: imbalance ratio = 2.21
#   Indian: imbalance ratio = 1.07
#   White: imbalance ratio = 1.12
#
# Val Set:
#
# Gender distribution by race:
# gender           Female   Male
# race
# Black             50.00  50.00
# East Asian        49.98  50.02
# Indian            48.24  51.76
# Latino_Hispanic   50.33  49.67
# Middle Eastern    31.14  68.86
# Southeast Asian   48.03  51.97
# White             47.24  52.76
#   East Asian: imbalance ratio = 1.00
#   Indian: imbalance ratio = 1.07
#   Latino_Hispanic: imbalance ratio = 1.01
#   Black: imbalance ratio = 1.00
#   Southeast Asian: imbalance ratio = 1.08
#   White: imbalance ratio = 1.12
#   Middle Eastern: imbalance ratio = 2.21
#
# Test Set:
#
# Gender distribution by race:
# gender           Female   Male
# race
# Black             50.00  50.00
# East Asian        49.95  50.05
# Indian            48.22  51.78
# Latino_Hispanic   50.33  49.67
# Middle Eastern    31.09  68.91
# Southeast Asian   48.01  51.99
# White             47.21  52.79
#   East Asian: imbalance ratio = 1.00
#   Latino_Hispanic: imbalance ratio = 1.01
#   Middle Eastern: imbalance ratio = 2.22
#   White: imbalance ratio = 1.12
#   Indian: imbalance ratio = 1.07
#   Southeast Asian: imbalance ratio = 1.08
#   Black: imbalance ratio = 1.00
#
# ============================================================
# PREPROCESSING COMPLETE!
# ============================================================
#
# Outputs saved to: /content/drive/MyDrive/FinalProject_DL/processed_data
# Files created:
#   - label_encodings.json
#   - split_indices.json
#   - train_split.csv
#   - val_split.csv
#   - test_split.csv

# %% [markdown]
# #CNN Models:
#
# **Architecture:**
#
# - Three ImageNet models, such as **InceptionResnetV2, EfficientNetV2, and ConvNeXt**
# - Load ImageNet-pretrained Model
# - Replace final fully-connected layer with 2-unit output for binary gender classification.
#
# Proposed Methods:
#
# Baseline Models: Train CNN  as baseline classifiers, evaluating overall accuracy alongside race stratified metrics including Demographic Parity Gap and Equalized Odds Gap. This establishes whether each architecture reproduces race-dependent disparities.

# %% [markdown]
# ##Build the model - InceptionResnetV2

# %%
import timm
import torch
import torch.nn as nn

def build_inceptionresnetv2_baseline(num_classes=2, pretrained=True):
    model = timm.create_model("inception_resnet_v2", pretrained=pretrained)

    # timm InceptionResNetV2 uses `classifier`
    #in_features = model.classifier.in_features
    in_features = model.classif.in_features
    model.classifier = nn.Linear(in_features, num_classes)

    return model

# %%
from tqdm import tqdm

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    running_loss, correct, total = 0.0, 0, 0

    for batch in tqdm(loader, desc="Training", leave=False):
        images = batch["image"].to(device)
        labels = batch["gender"].to(device)

        optimizer.zero_grad()
        logits = model(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * labels.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    return running_loss / total, correct / total


@torch.no_grad()
def eval_model(model, loader, criterion, device):
    model.eval()
    running_loss, correct, total = 0.0, 0, 0

    all_preds = []
    all_labels = []
    all_races = []

    for batch in tqdm(loader, desc="Evaluating", leave=False):
        images = batch["image"].to(device)
        labels = batch["gender"].to(device)
        races  = batch["race"].to(device)

        logits = model(images)
        loss = criterion(logits, labels)

        running_loss += loss.item() * labels.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())
        all_races.append(races.cpu())

    all_preds  = torch.cat(all_preds)
    all_labels = torch.cat(all_labels)
    all_races  = torch.cat(all_races)

    return (running_loss / total, correct / total,
            all_preds, all_labels, all_races)

# %%
import numpy as np
import pandas as pd

def compute_fairness_metrics(preds, labels, races, num_races=7):
    preds = preds.numpy()
    labels = labels.numpy()
    races = races.numpy()

    per_race = {}
    pos_rate_by_race = []
    tpr_by_race = []
    fpr_by_race = []

    for r in range(num_races):
        idx = races == r
        if idx.sum() == 0:
            continue

        pr = preds[idx]
        yl = labels[idx]

        pos_rate = pr.mean()
        pos_rate_by_race.append(pos_rate)

        pos_idx = (yl == 1)
        neg_idx = (yl == 0)

        tpr = pr[pos_idx].mean() if pos_idx.sum() > 0 else np.nan
        fpr = pr[neg_idx].mean() if neg_idx.sum() > 0 else np.nan
        tpr_by_race.append(tpr)
        fpr_by_race.append(fpr)

        acc = (pr == yl).mean()

        per_race[r] = {
            "count": int(idx.sum()),
            "accuracy": float(acc),
            "pos_rate": float(pos_rate),
            "tpr": float(tpr) if not np.isnan(tpr) else None,
            "fpr": float(fpr) if not np.isnan(fpr) else None
        }

    dp_gap = float(np.nanmax(pos_rate_by_race) - np.nanmin(pos_rate_by_race)) if len(pos_rate_by_race) else np.nan
    tpr_gap = float(np.nanmax(tpr_by_race) - np.nanmin(tpr_by_race)) if len(tpr_by_race) else np.nan
    fpr_gap = float(np.nanmax(fpr_by_race) - np.nanmin(fpr_by_race)) if len(fpr_by_race) else np.nan
    eo_gap = np.nanmax([tpr_gap, fpr_gap])

    return {
        "per_race": per_race,
        "dp_gap": dp_gap,
        "tpr_gap": tpr_gap,
        "fpr_gap": fpr_gap,
        "eo_gap": float(eo_gap) if not np.isnan(eo_gap) else np.nan
    }

def fairness_report(metrics, race_map=None):
    rows = []
    for r, stats in metrics["per_race"].items():
        race_name = race_map.get(r, str(r)) if race_map else str(r)
        rows.append({
            "race": race_name,
            "count": stats["count"],
            "accuracy": stats["accuracy"],
            "pos_rate": stats["pos_rate"],
            "tpr": stats["tpr"],
            "fpr": stats["fpr"],
        })
    df = pd.DataFrame(rows)
    return df.sort_values("race"), metrics["dp_gap"], metrics["eo_gap"]

# %%
import torch.optim as optim

def run_inceptionresnetv2_baseline(train_loader, val_loader, test_loader, label_encodings,
                                  epochs=5, lr=1e-4, weight_decay=1e-4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = build_inceptionresnetv2_baseline(num_classes=2, pretrained=True).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_val_acc = 0.0
    best_state = None

    for ep in range(1, epochs + 1):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc, _, _, _ = eval_model(model, val_loader, criterion, device)

        print(f"Epoch {ep}/{epochs} | "
              f"Train loss {train_loss:.4f}, acc {train_acc:.4f} | "
              f"Val loss {val_loss:.4f}, acc {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}

    # Load best checkpoint
    model.load_state_dict(best_state)

    # Test evaluation + fairness
    test_loss, test_acc, preds, labels, races = eval_model(model, test_loader, criterion, device)
    metrics = compute_fairness_metrics(preds, labels, races, num_races=len(label_encodings["race"]))

    # Pretty report
    race_inv_map = {v: k for k, v in label_encodings["race"].items()}
    df_report, dp_gap, eo_gap = fairness_report(metrics, race_map=race_inv_map)

    print("\n=== BASELINE RESULTS: InceptionResNetV2 ===")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Demographic Parity Gap (race): {dp_gap:.4f}")
    print(f"Equalized Odds Gap (race): {eo_gap:.4f}")
    print("\nPer-race breakdown:")
    print(df_report.to_string(index=False))

    return model, df_report, metrics

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def run_inceptionresnetv2_baseline(train_loader, val_loader, test_loader, label_encodings,
                                  epochs=5, lr=1e-4, weight_decay=1e-4):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = build_inceptionresnetv2_baseline(num_classes=2, pretrained=True).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_val_acc = 0.0
    best_state = None

    for ep in range(1, epochs + 1):
        train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion, device)
        val_loss, val_acc, _, _, _ = eval_model(model, val_loader, criterion, device)

        print(f"Epoch {ep}/{epochs} | "
              f"Train loss {train_loss:.4f}, acc {train_acc:.4f} | "
              f"Val loss {val_loss:.4f}, acc {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state = {k: v.cpu() for k, v in model.state_dict().items()}

    # Load best checkpoint safely
    if best_state is not None:
        model.load_state_dict(best_state)

    # Test evaluation + fairness
    test_loss, test_acc, preds, labels, races = eval_model(model, test_loader, criterion, device)
    metrics = compute_fairness_metrics(preds, labels, races, num_races=len(label_encodings["race"]))

    # Pretty report
    race_inv_map = {v: k for k, v in label_encodings["race"].items()}
    df_report, dp_gap, eo_gap = fairness_report(metrics, race_map=race_inv_map)

    print("\n=== BASELINE RESULTS: InceptionResNetV2 (ImageNet Pretrained) ===")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Demographic Parity Gap (race): {dp_gap:.4f}")
    print(f"Equalized Odds Gap (race): {eo_gap:.4f}")
    print("\nPer-race breakdown:")
    print(df_report.to_string(index=False))

    return model, df_report, metrics

# %%
 umodel_Inception, df_report, metrics = run_inceptionresnetv2_baseline(
    train_loader,
    val_loader,
    test_loader,
    label_encodings,
    epochs=5,
    lr=1e-4,
    weight_decay=1e-4
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/224M [00:00<?, ?B/s]
# Epoch 1/5 | Train loss 0.3903, acc 0.8412 | Val loss 0.3348, acc 0.8961
# Epoch 2/5 | Train loss 0.2241, acc 0.9027 | Val loss 0.2608, acc 0.9113
# Epoch 3/5 | Train loss 0.1841, acc 0.9218 | Val loss 0.2180, acc 0.9146
# Epoch 4/5 | Train loss 0.1555, acc 0.9355 | Val loss 0.3272, acc 0.9049
# Epoch 5/5 | Train loss 0.1334, acc 0.9457 | Val loss 0.2000, acc 0.9254
# === BASELINE RESULTS: InceptionResNetV2 (ImageNet Pretrained) ===
# Test Accuracy: 0.9251
# Demographic Parity Gap (race): 0.2114
# Equalized Odds Gap (race): 0.1214
#
# Per-race breakdown:
#            race  count  accuracy  pos_rate      tpr      fpr
#           Black   2068  0.860251  0.515957 0.876209 0.155706
#      East Asian   2076  0.928709  0.527457 0.956606 0.099134
#          Indian   2076  0.950385  0.489403 0.956044 0.054884
# Latino_Hispanic   2249  0.934193  0.526456 0.957597 0.089526
#  Middle Eastern   1563  0.957774  0.316059 0.940329 0.034355
# Southeast Asian   1831  0.927908  0.492081 0.937429 0.080882
#           White   2792  0.924427  0.488181 0.937026 0.086839

# %% [markdown]
# ##Get test predictions from trained model

# %%
import torch
import numpy as np

@torch.no_grad()
def get_test_predictions(model, test_loader):
    device = next(model.parameters()).device
    model.eval()

    all_preds, all_labels, all_races = [], [], []

    for batch in test_loader:
        images = batch["image"].to(device)
        labels = batch["gender"].to(device)
        races  = batch["race"].to(device)

        logits = model(images)
        preds = logits.argmax(dim=1)

        all_preds.append(preds.cpu())
        all_labels.append(labels.cpu())
        all_races.append(races.cpu())

    all_preds  = torch.cat(all_preds).numpy()
    all_labels = torch.cat(all_labels).numpy()
    all_races  = torch.cat(all_races).numpy()

    return all_preds, all_labels, all_races


preds, labels, races = get_test_predictions(model_Inception, test_loader)
print(preds.shape, labels.shape, races.shape)
# Out:
# (14655,) (14655,) (14655,)

# %% [markdown]
# ##Overall confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Ensure confusion matrix only considers classes 0 and 1
cm = confusion_matrix(labels, preds, labels=[0, 1])

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=["Male (0)", "Female (1)"])
disp.plot(cmap="Blues", values_format="d")
plt.title("InceptionResNetV2 (ImageNet) — Overall Confusion Matrix")
plt.show()

print("Confusion matrix:\n", cm)
# Out:
# Confusion matrix:
#  [[7103  665]
#  [ 432 6455]]

# %% [markdown]
# ##Per-race confusion matrices

# %%
race_inv_map = {v: k for k, v in label_encodings["race"].items()}

for r_id, r_name in race_inv_map.items():
    idx = races == r_id
    if idx.sum() == 0:
        continue

    cm_r = confusion_matrix(labels[idx], preds[idx])
    disp_r = ConfusionMatrixDisplay(confusion_matrix=cm_r,
                                    display_labels=["Male (0)", "Female (1)"])
    disp_r.plot(cmap="Blues", values_format="d")
    plt.title(f"InceptionResNetV2 — Confusion Matrix (Race: {r_name})")
    plt.show()

# %% [markdown]
# ##Accuracy by race plot

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9,5))
plt.bar(df_report["race"], df_report["accuracy"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("Accuracy")
plt.title("InceptionResNetV2 (ImageNet) — Test Accuracy by Race")
plt.ylim(0.75, 1.0)
plt.show()

# %% [markdown]
# ##Positive prediction rate by race (DP - Demographic Parity Gap)

# %%
plt.figure(figsize=(9,5))
plt.bar(df_report["race"], df_report["pos_rate"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("P(ŷ = 1)  (Predicted Female Rate)")
plt.title("InceptionResNetV2 — Demographic Parity View by Race")
plt.show()

# %% [markdown]
# #TPR / FPR by race (EO view)

# %%
import numpy as np

x = np.arange(len(df_report["race"]))
width = 0.35

plt.figure(figsize=(10,5))
plt.bar(x - width/2, df_report["tpr"], width, label="TPR")
plt.bar(x + width/2, df_report["fpr"], width, label="FPR")

plt.xticks(x, df_report["race"], rotation=45, ha="right")
plt.ylabel("Rate")
plt.title("InceptionResNetV2 — Equalized Odds View by Race")
plt.legend()
plt.show()
